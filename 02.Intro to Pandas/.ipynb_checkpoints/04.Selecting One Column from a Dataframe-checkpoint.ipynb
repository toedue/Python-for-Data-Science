# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Selecting one column

# %% [markdown]
# ### Syntax 1

# %%
# select a column with sqaure bracket -> [] (preferred way to select a column in pandas)
df_exams['gender']

# this is an array (a 1d array) series
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# check out the data type of a column
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# in series, just like pandas dataframes have attributes and methods and are very similar
# series: attributes and methods
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ### Syntax 2

# %%
# select a column with . (dot sign)
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# select a column with . (pitfalls) 
df_exams.math score

# u get an error because there id no underscore between the two words
# Out:
#   Cell In[12], line 2
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %%
# select the same column using []
df_exams["math score"]
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64
