# %%
import pandas as pd

# %% [markdown]
# # Read a .csv from a URL with Pandas
# Target website: https://www.football-data.co.uk/data.php

# %% [markdown]
# ### What is Web Scraping?
# Web scraping is the process of automatically collecting data from websites using code.
#
# Instead of copying data manually, you write a program to extract information from web pages.

# %%
# reading (extracting) 1 csv file from the website by read_csv method
df_premier25 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2526/E0.csv')

# %%
# showing dataframe
df_premier25
# Out:
#     Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00       Liverpool  Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30     Aston Villa    Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00        Brighton       Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00      Sunderland     West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00       Tottenham      Burnley     3     0   H     1
# ..   ..         ...    ...             ...          ...   ...   ...  ..   ...
# 296  E0  15/03/2026  14:00  Crystal Palace        Leeds     0     0   D     0
# 297  E0  15/03/2026  14:00      Man United  Aston Villa     3     1   H     0
# 298  E0  15/03/2026  14:00   Nott'm Forest       Fulham     0     0   D     0
# 299  E0  15/03/2026  16:30       Liverpool    Tottenham     1     1   D     1
# 300  E0  16/03/2026  20:00       Brentford       Wolves     2     2   D     2
#
#      HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0       0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1       0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2       0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3       0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4       0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
# ..    ...  ...      ...      ...    ...    ...      ...      ...      ...
# 296     0  ...     1.93     1.93    NaN    NaN     1.93     1.93     1.89
# 297     0  ...     1.90     1.95    NaN    NaN     1.93     1.96     1.88
# 298     0  ...     2.00     1.85    NaN    NaN     2.00     1.91     1.92
# 299     0  ...     1.80     2.00    NaN    NaN     1.85     2.05     1.77
# 300     1  ...     1.88     1.98    NaN    NaN     1.95     1.98     1.89
#
#      AvgCAHA  BFECAHH  BFECAHA
# 0       1.76     2.14     1.86
# 1       1.74     2.14     1.86
# 2       1.96     1.91     2.08
# 3       1.78     2.02     1.97
# 4       1.83     2.07     1.92
# ..       ...      ...      ...
# 296     1.88     2.01     1.97
# 297     1.90     1.96     2.02
# 298     1.85     2.04     1.93
# 299     1.96     1.88     2.11
# 300     1.89     1.93     2.05
#
# [301 rows x 132 columns]

# %%
# rename columns
df_premier25.rename(columns={'Date':'date','HomeTeam':'home_team',
                            'AwayTeam':'away_team', 'FTHG': 'home_goals',
                                'FTAG': 'away_goals'}, inplace=True)

# %%
# show dataframe
df_premier25
# Out:
#     Div        date   Time       home_team    away_team  home_goals  \
# 0    E0  15/08/2025  20:00       Liverpool  Bournemouth           4
# 1    E0  16/08/2025  12:30     Aston Villa    Newcastle           0
# 2    E0  16/08/2025  15:00        Brighton       Fulham           1
# 3    E0  16/08/2025  15:00      Sunderland     West Ham           3
# 4    E0  16/08/2025  15:00       Tottenham      Burnley           3
# ..   ..         ...    ...             ...          ...         ...
# 296  E0  15/03/2026  14:00  Crystal Palace        Leeds           0
# 297  E0  15/03/2026  14:00      Man United  Aston Villa           3
# 298  E0  15/03/2026  14:00   Nott'm Forest       Fulham           0
# 299  E0  15/03/2026  16:30       Liverpool    Tottenham           1
# 300  E0  16/03/2026  20:00       Brentford       Wolves           2
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0             2   H     1     0  ...     2.03     1.78   2.07   1.85     2.03
# 1             0   D     0     0  ...     2.05     1.80   2.02   1.89     2.06
# 2             1   D     0     0  ...     1.83     2.03   1.93   2.00     1.84
# 3             0   H     0     0  ...     1.95     1.90   1.97   1.95     1.95
# 4             0   H     1     0  ...     1.98     1.88   1.99   1.93     1.98
# ..          ...  ..   ...   ...  ...      ...      ...    ...    ...      ...
# 296           0   D     0     0  ...     1.93     1.93    NaN    NaN     1.93
# 297           1   H     0     0  ...     1.90     1.95    NaN    NaN     1.93
# 298           0   D     0     0  ...     2.00     1.85    NaN    NaN     2.00
# 299           1   D     1     0  ...     1.80     2.00    NaN    NaN     1.85
# 300           2   D     2     1  ...     1.88     1.98    NaN    NaN     1.95
#
#      MaxCAHA  AvgCAHH  AvgCAHA  BFECAHH  BFECAHA
# 0       1.88     1.94     1.76     2.14     1.86
# 1       1.80     1.95     1.74     2.14     1.86
# 2       2.03     1.80     1.96     1.91     2.08
# 3       1.94     1.86     1.78     2.02     1.97
# 4       1.91     1.88     1.83     2.07     1.92
# ..       ...      ...      ...      ...      ...
# 296     1.93     1.89     1.88     2.01     1.97
# 297     1.96     1.88     1.90     1.96     2.02
# 298     1.91     1.92     1.85     2.04     1.93
# 299     2.05     1.77     1.96     1.88     2.11
# 300     1.98     1.89     1.89     1.93     2.05
#
# [301 rows x 132 columns]

# %% [markdown]
# # Read .csv from Multiple URLs with Pandas
# https://www.football-data.co.uk/mmz4281/2526/E0.csv
#
# Link: root + season + league

# %%
# link structure
"https://www.football-data.co.uk/mmz4281/" + "2526" + "/" + "E0" + ".csv"
# Out:
# 'https://www.football-data.co.uk/mmz4281/2526/E0.csv'

# %%
# create a root variable (all the links have in common)
root = "https://www.football-data.co.uk/mmz4281/"
root
# Out:
# 'https://www.football-data.co.uk/mmz4281/'

# %% [markdown]
# ### Multiple leagues
#
# * https://www.football-data.co.uk/mmz4281/2526/E0.csv
# * https://www.football-data.co.uk/mmz4281/2526/E1.csv
# * https://www.football-data.co.uk/mmz4281/2526/E2.csv
# * https://www.football-data.co.uk/mmz4281/2526/E3.csv
# * https://www.football-data.co.uk/mmz4281/2526/EC.csv

# %%
# creating list of leagues
leagues = ['E0','E1', 'E2', 'E3', 'EC']

frames = []
# looping through leagues, read multiple csv and append it into a list
for league in leagues:
    df = pd.read_csv(root + "2526" + "/"  + league + ".csv")
    frames.append(df)

# %%
# length of frames
len(frames)
# Out:
# 5

# %%
# print(frames)

# %%
# show 1st element
frames[0].head(3)
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# 2     1.96     1.91     2.08
#
# [3 rows x 132 columns]

# %%
# show last element
frames[4].head(3)
# Out:
#   Div        Date   Time       HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  EC  09/08/2025  15:00     Altrincham  Aldershot     3     2   H     2
# 1  EC  09/08/2025  15:00   Boreham Wood   Rochdale     0     2   A     0
# 2  EC  09/08/2025  15:00  Brackley Town  Eastleigh     1     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...      1.9      1.9   1.92   1.93     1.90      1.9     1.86
# 1     0  ...      2.0      1.8   2.05   1.82     2.02      1.8     1.96
# 2     0  ...      2.0      1.8   2.14   1.72     2.03      1.8     1.96
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.84     2.00     1.99
# 1     1.75     2.06     1.89
# 2     1.75     2.06     1.84
#
# [3 rows x 124 columns]

# %% [markdown]
# ### Multiple Seasons

# %%
for season in range(20,26):
    print(season)
# Out:
# 20
# 21
# 22
# 23
# 24
# 25

# %%
for season in range(20,26):
    print(str(season) + str(season+1))
# Out:
# 2021
# 2122
# 2223
# 2324
# 2425
# 2526

# %%
leagues = ['E0','E2', 'E3']

frames = []

# loop through range of seasons and insert new column
for league in leagues:
    for season in range(20,26): # range of seasons
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + league + ".csv")
#         df['season'] = season   (add a season or a year column with the insert method) 
        df.insert(1, 'season', season) 
        # the first arg is the index where to put, then the name, value 
        frames.append(df)

# %%
# total frames (6 seasons x 3 leagues)
len(frames)
# Out:
# 18

# %%
# show element
frames[0].head(3)
# Out:
#   Div  season        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 0  E0      20  12/09/2020  12:30          Fulham      Arsenal     0     3   A
# 1  E0      20  12/09/2020  15:00  Crystal Palace  Southampton     1     0   H
# 2  E0      20  12/09/2020  17:30       Liverpool        Leeds     4     3   H
#
#    HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...      1.84  0.75     2.01      1.89   2.02   1.91     2.13
# 1     1  ...      1.70  0.25     1.78      2.13   1.79   2.17     1.85
# 2     3  ...      2.62 -1.50     1.85      2.05   1.85   2.08     1.90
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.92     2.02     1.87
# 1     2.18     1.79     2.12
# 2     2.16     1.84     2.04
#
# [3 rows x 107 columns]

# %%
# show the last element
frames[-1].head(3)
# Out:
#   Div  season        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0  E3      25  02/08/2025  15:00   Accrington      Gillingham     1     1   D
# 1  E3      25  02/08/2025  15:00       Barnet  Fleetwood Town     0     2   A
# 2  E3      25  02/08/2025  15:00  Bristol Rvs       Harrogate     0     1   A
#
#    HTHG  ...  B365CAHA PCAHH PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0     0  ...      1.88  1.76  2.12     1.98     1.88     1.92     1.83
# 1     0  ...      1.85  2.29  1.65     2.08     1.85     2.00     1.74
# 2     0  ...      2.03  1.85  2.00     1.85     2.03     1.78     1.96
#
#    BFECAHH  BFECAHA  Unnamed: 132
# 0     2.09     1.88           NaN
# 1     2.04     1.93           NaN
# 2     1.88     2.12           NaN
#
# [3 rows x 134 columns]

# %% [markdown]
# # Organize All The Data in a Dictionary

# %%
# create a dictionary with original name of league as key
dict_countries = {
              'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2',
              'German Bundesliga':'D1', 
              'English Premier League':'E0', 'English League 1':'E2', 'English League 2':'E3',
             }

# %%
# get a dictionary element
dict_countries['German Bundesliga']
# Out:
# 'D1'

# %%
# dict data to store all the dataframe been extracted
"""
Final structure will look like:
{
   'Spanish La Liga': dataframe,
   'German Bundesliga': dataframe,
   ...
}"""
dict_historical_data = {} 

# looping through key elements (Outer loop (loop through leagues))
for league in dict_countries:
    frames = [] # one dataframe per league (You will store multiple seasons (dataframes) here)
    for season in range(20,26): #Inner loop (loop through seasons)
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + dict_countries[league]+ ".csv")
        df.insert(1, 'season', season)  # Adds a new column called 'season' (At position index 1)
        frames.append(df) # Store each season's dataframe in the list
    df_frames = pd.concat(frames) # storing all seasons(from 20 to 26) of a league in a single dataframe
    dict_historical_data[league] = df_frames # assigning dataframe to a new dictionary

# %%
# show dataframe inside dict_historical_data
dict_historical_data['Spanish La Liga']
# Out:
#      Div  season        Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 0    SP1      20  12/09/2020  15:00       Eibar       Celta     0     0   D
# 1    SP1      20  12/09/2020  17:30     Granada  Ath Bilbao     2     0   H
# 2    SP1      20  12/09/2020  20:00       Cadiz     Osasuna     0     2   A
# 3    SP1      20  13/09/2020  13:00      Alaves       Betis     0     1   A
# 4    SP1      20  13/09/2020  15:00  Valladolid    Sociedad     1     1   D
# ..   ...     ...         ...    ...         ...         ...   ...   ...  ..
# 275  SP1      25  15/03/2026  13:00    Mallorca     Espanol     2     1   H
# 276  SP1      25  15/03/2026  15:15   Barcelona     Sevilla     5     2   H
# 277  SP1      25  15/03/2026  17:30       Betis       Celta     1     1   D
# 278  SP1      25  15/03/2026  20:00    Sociedad     Osasuna     3     1   H
# 279  SP1      25  16/03/2026  20:00   Vallecano     Levante     1     1   D
#
#      HTHG  ...  BMGMCA  BVCH  BVCD   BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  LBCA
# 0       0  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       0  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       0  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       0  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       1  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...  ...     ...   ...   ...    ...   ...   ...   ...   ...   ...   ...
# 275     0  ...    3.05  2.50   3.0   3.10   NaN   NaN   NaN   NaN   NaN   NaN
# 276     3  ...    9.50  1.25   6.5  10.50   NaN   NaN   NaN   NaN   NaN   NaN
# 277     0  ...    3.70  2.00   3.3   3.90   NaN   NaN   NaN   NaN   NaN   NaN
# 278     2  ...    4.10  1.95   3.6   3.80  1.95   3.6   3.9  1.91   3.5   3.8
# 279     0  ...    4.90  1.85   3.5   4.33   NaN   NaN   NaN   NaN   NaN   NaN
#
# [2180 rows x 162 columns]

# %%
dict_historical_data.keys()
# Out:
# dict_keys(['Spanish La Liga', 'Spanish Segunda Division', 'German Bundesliga', 'English Premier League', 'English League 1', 'English League 2'])

# %%
dict_historical_data.items()
# Out:
# dict_items([('Spanish La Liga',      Div  season        Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 0    SP1      20  12/09/2020  15:00       Eibar       Celta     0     0   D
# 1    SP1      20  12/09/2020  17:30     Granada  Ath Bilbao     2     0   H
# 2    SP1      20  12/09/2020  20:00       Cadiz     Osasuna     0     2   A
# 3    SP1      20  13/09/2020  13:00      Alaves       Betis     0     1   A
# 4    SP1      20  13/09/2020  15:00  Valladolid    Sociedad     1     1   D
# ..   ...     ...         ...    ...         ...         ...   ...   ...  ..
# 275  SP1      25  15/03/2026  13:00    Mallorca     Espanol     2     1   H
# 276  SP1      25  15/03/2026  15:15   Barcelona     Sevilla     5     2   H
# 277  SP1      25  15/03/2026  17:30       Betis       Celta     1     1   D
# 278  SP1      25  15/03/2026  20:00    Sociedad     Osasuna     3     1   H
# 279  SP1      25  16/03/2026  20:00   Vallecano     Levante     1     1   D
#
#      HTHG  ...  BMGMCA  BVCH  BVCD   BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  LBCA
# 0       0  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       0  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       0  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       0  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       1  ...     NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...  ...     ...   ...   ...    ...   ...   ...   ...   ...   ...   ...
# 275     0  ...    3.05  2.50   3.0   3.10   NaN   NaN   NaN   NaN   NaN   NaN
# 276     3  ...    9.50  1.25   6.5  10.50   NaN   NaN   NaN   NaN   NaN   NaN
# 277     0  ...    3.70  2.00   3.3   3.90   NaN   NaN   NaN   NaN   NaN   NaN
# 278     2  ...    4.10  1.95   3.6   3.80  1.95   3.6   3.9  1.91   3.5   3.8
# 279     0  ...    4.90  1.85   3.5   4.33   NaN   NaN   NaN   NaN   NaN   NaN
#
# [2180 rows x 162 columns]), ('Spanish Segunda Division',      Div  season        Date   Time      HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 0    SP2      20  12/09/2020  15:00  Ponferradina   Castellon     1     2   A
# 1    SP2      20  12/09/2020  17:15       Leganes  Las Palmas     1     0   H
# 2    SP2      20  12/09/2020  17:15      Sp Gijon    Logrones     1     0   H
# 3    SP2      20  12/09/2020  20:00       Espanol    Albacete     3     0   H
# 4    SP2      20  13/09/2020  11:00        Oviedo   Cartagena     0     0   D
# ..   ...     ...         ...    ...           ...         ...   ...   ...  ..
# 325  SP2      25  15/03/2026  15:15       Granada     Andorra     1     1   D
# 326  SP2      25  15/03/2026  17:30         Eibar      Burgos     0     0   D
# 327  SP2      25  15/03/2026  17:30        Malaga      Huesca     5     3   H
# 328  SP2      25  15/03/2026  20:00      Sp Gijon   Castellon     4     1   H
# 329  SP2      25  16/03/2026  19:30      Albacete  Las Palmas     2     1   H
#
#      HTHG  ...  BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  LBCA
# 0       1  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       2  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...  ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 325     1  ...    3.90  2.00  3.25  3.50   NaN   NaN   NaN   NaN   NaN   NaN
# 326     0  ...    3.95  2.00  2.88  4.10  2.00   2.8  3.75  2.00   2.8  3.75
# 327     2  ...    4.90  1.62  3.50  5.25  1.65   3.4  4.80  1.65   3.4  4.80
# 328     1  ...    2.12  3.30  3.40  2.00  3.20   3.4  1.95  3.20   3.4  1.95
# 329     0  ...    2.63  2.75  3.10  2.45   NaN   NaN   NaN   NaN   NaN   NaN
#
# [2640 rows x 162 columns]), ('German Bundesliga',     Div  season        Date   Time       HomeTeam       AwayTeam  FTHG  FTAG  \
# 0    D1      20  18/09/2020  19:30  Bayern Munich     Schalke 04     8     0
# 1    D1      20  19/09/2020  14:30  Ein Frankfurt      Bielefeld     1     1
# 2    D1      20  19/09/2020  14:30        FC Koln     Hoffenheim     2     3
# 3    D1      20  19/09/2020  14:30      Stuttgart       Freiburg     2     3
# 4    D1      20  19/09/2020  14:30   Union Berlin       Augsburg     1     3
# ..   ..     ...         ...    ...            ...            ...   ...   ...
# 229  D1      25  14/03/2026  14:30     Leverkusen  Bayern Munich     1     1
# 230  D1      25  14/03/2026  17:30        Hamburg        FC Koln     1     1
# 231  D1      25  15/03/2026  14:30  Werder Bremen          Mainz     0     2
# 232  D1      25  15/03/2026  16:30       Freiburg   Union Berlin     0     1
# 233  D1      25  15/03/2026  18:30      Stuttgart     RB Leipzig     1     0
#
#     FTR  HTHG  ...  BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  \
# 0     H   3.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     D   0.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     A   1.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     A   0.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     A   0.0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ..   ...  ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 229   D   1.0  ...    1.53  5.00  4.75  1.53   NaN   NaN   NaN   NaN   NaN
# 230   D   1.0  ...    2.90  2.30  3.50  2.90   NaN   NaN   NaN   NaN   NaN
# 231   A   0.0  ...    3.15  2.25  3.60  2.90   NaN   NaN   NaN   NaN   NaN
# 232   A   0.0  ...    3.90  1.87  3.60  4.00   NaN   NaN   NaN   NaN   NaN
# 233   H   0.0  ...    2.50  2.40  4.00  2.50  2.37   3.9  2.62  2.37   3.9
#
#      LBCA
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 229   NaN
# 230   NaN
# 231   NaN
# 232   NaN
# 233   2.6
#
# [1764 rows x 162 columns]), ('English Premier League',     Div  season        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG  \
# 0    E0      20  12/09/2020  12:30          Fulham      Arsenal     0     3
# 1    E0      20  12/09/2020  15:00  Crystal Palace  Southampton     1     0
# 2    E0      20  12/09/2020  17:30       Liverpool        Leeds     4     3
# 3    E0      20  12/09/2020  20:00        West Ham    Newcastle     0     2
# 4    E0      20  13/09/2020  14:00       West Brom    Leicester     0     3
# ..   ..     ...         ...    ...             ...          ...   ...   ...
# 296  E0      25  15/03/2026  14:00  Crystal Palace        Leeds     0     0
# 297  E0      25  15/03/2026  14:00      Man United  Aston Villa     3     1
# 298  E0      25  15/03/2026  14:00   Nott'm Forest       Fulham     0     0
# 299  E0      25  15/03/2026  16:30       Liverpool    Tottenham     1     1
# 300  E0      25  16/03/2026  20:00       Brentford       Wolves     2     2
#
#     FTR  HTHG  ...  BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  \
# 0     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     H     1  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     H     3  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ..   ...  ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 296   D     0  ...     2.7  2.63  3.30   2.7   NaN   NaN   NaN   NaN   NaN
# 297   H     0  ...     4.7  1.70  4.00   4.6   NaN   NaN   NaN   NaN   NaN
# 298   D     0  ...     3.2  2.30  3.40   3.1   NaN   NaN   NaN   NaN   NaN
# 299   D     1  ...     8.5  1.30  6.00   8.5   NaN   NaN   NaN   NaN   NaN
# 300   D     2  ...     5.8  1.53  4.33   6.0   NaN   NaN   NaN   NaN   NaN
#
#      LBCA
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 296   NaN
# 297   NaN
# 298   NaN
# 299   NaN
# 300   NaN
#
# [2201 rows x 163 columns]), ('English League 1',     Div  season        Date   Time        HomeTeam            AwayTeam  FTHG  \
# 0    E2      20  12/09/2020  15:00      Accrington           Peterboro     2
# 1    E2      20  12/09/2020  15:00           Crewe            Charlton     0
# 2    E2      20  12/09/2020  15:00       Doncaster  Milton Keynes Dons     1
# 3    E2      20  12/09/2020  15:00  Fleetwood Town              Burton     2
# 4    E2      20  12/09/2020  15:00      Gillingham                Hull     0
# ..   ..     ...         ...    ...             ...                 ...   ...
# 431  E2      25  14/03/2026  15:00       Port Vale        Huddersfield     0
# 432  E2      25  14/03/2026  15:00         Reading            Plymouth     2
# 433  E2      25  14/03/2026  15:00       Stevenage       AFC Wimbledon     1
# 434  E2      25  14/03/2026  15:00           Wigan            Bradford     2
# 435  E2      25  14/03/2026  15:00         Wycombe               Luton     1
#
#      FTAG FTR  HTHG  ...  BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  \
# 0       0   H     1  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       2   A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       1   D     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       1   H     1  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       2   A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...  ..   ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 431     0   D     0  ...    1.97  4.40  3.40  1.83  4.20  3.50  1.91  4.20
# 432     2   D     2  ...    2.40  2.90  3.50  2.30  3.00  3.70  2.25  2.90
# 433     0   H     1  ...    3.85  1.95  3.25  4.10  2.05  3.25  3.80  2.05
# 434     0   H     1  ...    2.25  3.40  3.25  2.15  3.30  3.30  2.20  3.30
# 435     2   A     0  ...    3.70  2.15  3.40  3.30  2.15  3.40  3.40  2.15
#
#      LBCD  LBCA
# 0     NaN   NaN
# 1     NaN   NaN
# 2     NaN   NaN
# 3     NaN   NaN
# 4     NaN   NaN
# ..    ...   ...
# 431   3.4  1.91
# 432   3.6  2.20
# 433   3.2  3.80
# 434   3.3  2.15
# 435   3.4  3.30
#
# [3196 rows x 163 columns]), ('English League 2',     Div  season        Date   Time        HomeTeam            AwayTeam  FTHG  \
# 0    E3      20  12/09/2020  15:00          Barrow           Stevenage     1
# 1    E3      20  12/09/2020  15:00          Bolton        Forest Green     0
# 2    E3      20  12/09/2020  15:00        Bradford          Colchester     0
# 3    E3      20  12/09/2020  15:00       Cambridge            Carlisle     3
# 4    E3      20  12/09/2020  15:00      Cheltenham           Morecambe     1
# ..   ..     ...         ...    ...             ...                 ...   ...
# 434  E3      25  14/03/2026  15:00           Crewe             Walsall     0
# 435  E3      25  14/03/2026  15:00  Fleetwood Town            Tranmere     0
# 436  E3      25  14/03/2026  15:00          Oldham             Grimsby     1
# 437  E3      25  14/03/2026  15:00      Shrewsbury          Cheltenham     0
# 438  E3      25  14/03/2026  15:00         Swindon  Milton Keynes Dons     1
#
#      FTAG FTR  HTHG  ...  BVCH BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  LBCA  \
# 0       1   D     1  ...   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       1   A     0  ...   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       0   D     0  ...   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       0   H     2  ...   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       2   A     1  ...   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...  ..   ...  ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 434     3   A     0  ...  2.30  3.3  3.10  2.37   3.3  3.00  2.37   3.3   3.0
# 435     0   D     0  ...  1.70  3.7  4.75  1.75   3.6  4.60  1.75   3.6   4.6
# 436     0   H     0  ...  2.55  3.3  2.70  2.60   3.3  2.70  2.60   3.3   2.7
# 437     2   A     0  ...  2.00  3.3  3.80  2.00   3.3  3.90  2.00   3.3   3.8
# 438     2   A     0  ...  3.00  3.4  2.30  3.10   3.4  2.25  3.10   3.4   2.2
#
#      Unnamed: 132
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 434           NaN
# 435           NaN
# 436           NaN
# 437           NaN
# 438           NaN
#
# [3199 rows x 164 columns])])

# %%
dict_historical_data['English Premier League']
# Out:
#     Div  season        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG  \
# 0    E0      20  12/09/2020  12:30          Fulham      Arsenal     0     3
# 1    E0      20  12/09/2020  15:00  Crystal Palace  Southampton     1     0
# 2    E0      20  12/09/2020  17:30       Liverpool        Leeds     4     3
# 3    E0      20  12/09/2020  20:00        West Ham    Newcastle     0     2
# 4    E0      20  13/09/2020  14:00       West Brom    Leicester     0     3
# ..   ..     ...         ...    ...             ...          ...   ...   ...
# 296  E0      25  15/03/2026  14:00  Crystal Palace        Leeds     0     0
# 297  E0      25  15/03/2026  14:00      Man United  Aston Villa     3     1
# 298  E0      25  15/03/2026  14:00   Nott'm Forest       Fulham     0     0
# 299  E0      25  15/03/2026  16:30       Liverpool    Tottenham     1     1
# 300  E0      25  16/03/2026  20:00       Brentford       Wolves     2     2
#
#     FTR  HTHG  ...  BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  \
# 0     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     H     1  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     H     3  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     A     0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ..   ...  ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 296   D     0  ...     2.7  2.63  3.30   2.7   NaN   NaN   NaN   NaN   NaN
# 297   H     0  ...     4.7  1.70  4.00   4.6   NaN   NaN   NaN   NaN   NaN
# 298   D     0  ...     3.2  2.30  3.40   3.1   NaN   NaN   NaN   NaN   NaN
# 299   D     1  ...     8.5  1.30  6.00   8.5   NaN   NaN   NaN   NaN   NaN
# 300   D     2  ...     5.8  1.53  4.33   6.0   NaN   NaN   NaN   NaN   NaN
#
#      LBCA
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 296   NaN
# 297   NaN
# 298   NaN
# 299   NaN
# 300   NaN
#
# [2201 rows x 163 columns]
